# %% [markdown]
# # Applied Information Analyst Series
# ### A1: The illusion of immeasurability
# ##### Febuary 20th, 2018

# %%
import numpy as np
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\configparser.py in _unify_values(self, section, vars)
#    1137         try:
# -> 1138             sectiondict = self._sections[section]
#    1139         except KeyError:
#
# KeyError: 'blas'
#
# During handling of the above exception, another exception occurred:
#
# NoSectionError                            Traceback (most recent call last)
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\configparser.py in fetch_val_for_key(key, delete_key)
#     167         try:
# --> 168             return theano_cfg.get(section, option)
#     169         except ConfigParser.InterpolationError:
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\configparser.py in get(self, section, option, raw, vars, fallback)
#     780         try:
# --> 781             d = self._unify_values(section, vars)
#     782         except NoSectionError:
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\configparser.py in _unify_values(self, section, vars)
#    1140             if section != self.default_section:
# -> 1141                 raise NoSectionError(section)
#    1142         # Update with the entry specific variables
#
# NoSectionError: No section: 'blas'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\configparser.py in __get__(self, cls, type_, delete_key)
#     327                 val_str = fetch_val_for_key(self.fullname,
# --> 328                                             delete_key=delete_key)
#     329                 self.is_default = False
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\configparser.py in fetch_val_for_key(key, delete_key)
#     171     except (ConfigParser.NoOptionError, ConfigParser.NoSectionError):
# --> 172         raise KeyError(key)
#     173
#
# KeyError: 'blas.ldflags'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-899c9dbc3cd4> in <module>()
#       1 import numpy as np
#       2 import seaborn as sns
# ----> 3 import pymc3 as pm
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\pymc3\__init__.py in <module>()
#       3
#       4 from .blocking import *
# ----> 5 from .distributions import *
#       6 from .external import *
#       7 from .glm import *
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\pymc3\distributions\__init__.py in <module>()
# ----> 1 from . import timeseries
#       2 from . import transforms
#       3
#       4 from .continuous import Uniform
#       5 from .continuous import Flat
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\pymc3\distributions\timeseries.py in <module>()
# ----> 1 import theano.tensor as tt
#       2 from theano import scan
#       3
#       4 from pymc3.util import get_variable_name
#       5 from .continuous import get_tau_sd, Normal, Flat
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\__init__.py in <module>()
#     122 from theano.printing import pprint, pp
#     123
# --> 124 from theano.scan_module import (scan, map, reduce, foldl, foldr, clone,
#     125                                 scan_checkpoints)
#     126
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\scan_module\__init__.py in <module>()
#      39 __contact__ = "Razvan Pascanu <r.pascanu@gmail>"
#      40
# ---> 41 from theano.scan_module import scan_opt
#      42 from theano.scan_module.scan import scan
#      43 from theano.scan_module.scan_checkpoints import scan_checkpoints
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\scan_module\scan_opt.py in <module>()
#      58
#      59 import theano
# ---> 60 from theano import tensor, scalar
#      61 from theano.tensor import opt, get_scalar_constant_value, Alloc, AllocEmpty
#      62 from theano import gof
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\tensor\__init__.py in <module>()
#      15 from theano.tensor import opt
#      16 from theano.tensor import opt_uncanonicalize
# ---> 17 from theano.tensor import blas
#      18 from theano.tensor import blas_scipy
#      19 from theano.tensor import blas_c
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\tensor\blas.py in <module>()
#     153 from theano.scalar import bool as bool_t
#     154 from theano.tensor import basic as T
# --> 155 from theano.tensor.blas_headers import blas_header_text
#     156 from theano.tensor.blas_headers import blas_header_version
#     157 from theano.tensor.opt import in2out, local_dimshuffle_lift
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\tensor\blas_headers.py in <module>()
#     985
#     986
# --> 987 if not config.blas.ldflags:
#     988     _logger.warning('Using NumPy C-API based implementation for BLAS functions.')
#     989
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\configparser.py in __get__(self, cls, type_, delete_key)
#     330             except KeyError:
#     331                 if callable(self.default):
# --> 332                     val_str = self.default()
#     333                 else:
#     334                     val_str = self.default
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\configdefaults.py in default_blas_ldflags()
#    1428         if res:
#    1429             if 'mkl' in res:
# -> 1430                 check_mkl_openmp()
#    1431             return res
#    1432
#
# ~\AppData\Local\Continuum\Anaconda3\envs\bayes\lib\site-packages\theano\configdefaults.py in check_mkl_openmp()
#    1250         import mkl
#    1251         if '2018' in mkl.get_version_string():
# -> 1252             raise RuntimeError('To use MKL 2018 with Theano you MUST set "MKL_THREADING_LAYER=GNU" in your environement.')
#    1253     except ImportError:
#    1254         raise RuntimeError("""
#
# RuntimeError: To use MKL 2018 with Theano you MUST set "MKL_THREADING_LAYER=GNU" in your environement.

# %% [markdown]
# Q: Why wouldn't we want to measure something?
# A: If the cost of the measurement exceeds the value of the information
#
# ### So what is measurement?
# The reduction of uncertainty.  The amount of reduciton corresponds to the value of that measurement. The key thing, in this framework we must consistantly think of outcomes in terms of probability distribuiton.
#
# ### 5 Sample Trick
# If you want to predict the median of a distribuiton, then with a sample of 5 you can be 93.5% that the median is contained between the minimum and the maximum of the sample.  This rule can actually be generalized based on the number of samples.  You can also how many samples from the max you look at.  So for 23 samples, we can look the 8th values from the min and max and still have ~93% confidence that the median is in that range.  ~~I would love to simulate this directly.~~ Modeled!  Have fun playing below!

# %%
from utils.population import Population
population = Population(50, 20)

# %%
population.plot_ixs(sample_size=50, ix_high=50)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x = np.random.normal(loc=10, scale=8, size=100)
y = np.random.normal(loc=9.5, scale=4, size=100)
sns.kdeplot(x, ax=ax)
sns.kdeplot(y, ax=ax)
ax.set_ylim(0, 0.1)
# Out:
# (0, 0.1)

# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
from ipywidgets import interact
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7cf7e907-98ca-491d-804f-fab6ac1bd2d2">Loading BokehJS ...</span>
#     </div>

# %%
x = range(1, 5)
y = population.get_prob_for_ixs(sample_size=5, ix_high=5)

# %%
p = figure()
r = p.line(x, y)

# %%
@interact(sample_size=(1, 1000), continuous_update=False)
def update(sample_size=5):
    r.data_source.data = {'x': range(1, sample_size), 
                          'y': population.get_prob_for_ixs(sample_size=sample_size, 
                                                          ix_high=sample_size,
                                                          ix_low=1)}
    show(p, notebook_handle=True)
# Out:
# interactive(children=(IntSlider(value=5, description='sample_size', max=1000, min=1), Output()), _dom_classes=('widget-interact',))
